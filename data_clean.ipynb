# %%
import json
import pandas as pd
from pathlib import Path

# Thư mục chứa các file .jsonl
input_folder = Path(r"D:\MangXaHoi\output_rows1")   
# Thư mục xuất file CSV
output_folder = Path(r"D:\MangXaHoi\gameshow_vietnam\file_csv1")
output_folder.mkdir(parents=True, exist_ok=True)

# Duyệt tất cả file .jsonl trong thư mục
for jsonl_file in input_folder.glob("*.jsonl"):
    records = []
    with open(jsonl_file, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                obj = json.loads(line)
                records.append(obj)
            except Exception as e:
                print(f"Lỗi parse dòng trong {jsonl_file}: {e}")

    if not records:
        print(f"[WARN] File {jsonl_file} không có dữ liệu.")
        continue

    df = pd.DataFrame(records)

    # Xuất file CSV với cùng tên vào thư mục file_csv
    csv_file = output_folder / (jsonl_file.stem + ".csv")
    df.to_csv(csv_file, index=False, encoding="utf-8-sig")
    print(f"[OK] {jsonl_file.name} → {csv_file}")

# %%
import re
import pandas as pd
from pathlib import Path
import json

# Thư mục chứa các file CSV gốc
INPUT_DIR = Path(r"D:/MangXaHoi/gameshow_vietnam/file_csv1")
# Thư mục lưu file CSV tên nghệ sĩ tương ứng
OUTPUT_DIR = Path(r"D:/MangXaHoi/gameshow_vietnam/artists_csv1")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# Regex nhận diện tên tiếng Việt
VI_NAME_RE = re.compile(
    r"\b([A-ZÀ-ỴĐ][a-zà-ỹđ]+(?:\s+[A-ZÀ-ỴĐ][a-zà-ỹđ]+){1,4})\b"
)

def normalize(s: str) -> str:
    return re.sub(r"\s+", " ", (s or "").strip())

def extract_names_from_text(text: str):
    """Trích tất cả tên trong 1 ô"""
    text = normalize(str(text))
    text = re.sub(r"[;/•|]", ",", text)  # chuẩn hóa phân tách
    names = set()
    for m in VI_NAME_RE.finditer(text):
        names.add(normalize(m.group(1)))
    return names

def pick_name_columns(df: pd.DataFrame):
    """Chọn cột khả năng là tên"""
    NAME_HINTS = ["Tên", "thành viên", "nghệ sĩ", "artist", "member", "cast", "Khách mời", "Thành viên", "Anh trai", "Tên nghệ sĩ", 
    "Em xinh", "MC", "Trưởng Phòng", "Khách mời 1" ,"Khách mời 2" ,"Khách mời 3", "Khách mời 4", "Huấn luyện viên", "Giám khảo", "Thí sinh", "Chỉ huy"]
    cols = [c for c in df.columns if any(kw in str(c).lower() for kw in NAME_HINTS)]
    if cols:
        return cols
    # fallback: chọn cột có nhiều ô khớp regex tên nhất
    scores = {}
    for c in df.columns:
        cnt = sum(bool(extract_names_from_text(v)) for v in df[c].astype(str).head(40))
        scores[c] = cnt
    if scores:
        best = max(scores, key=scores.get)
        return [best]
    return []

# Xử lý từng file
for csv_file in INPUT_DIR.glob("*.csv"):
    try:
        df = pd.read_csv(csv_file, encoding="utf-8-sig")
    except:
        df = pd.read_csv(csv_file, encoding="utf-8")

    name_cols = pick_name_columns(df)
    artist_names = set()

    if name_cols:
        for col in name_cols:
            for val in df[col]:
                artist_names.update(extract_names_from_text(val))
        print(f"[{csv_file.name}] → Cột tên: {name_cols}")
    else:
        # fallback: quét toàn bộ bảng
        for col in df.columns:
            for val in df[col]:
                artist_names.update(extract_names_from_text(val))
        print(f"[{csv_file.name}] → Không rõ cột tên, quét toàn bảng.")

    # Làm sạch, sắp xếp
    cleaned = sorted(n for n in artist_names if len(n.split()) >= 2)

    # Lưu ra CSV tương ứng
    out_file = OUTPUT_DIR / (csv_file.stem + "_artists.csv")
    pd.DataFrame({"artist_name": cleaned}).to_csv(out_file, index=False, encoding="utf-8-sig")
    print(f"[OK] Lưu {len(cleaned)} tên vào {out_file}")
# Out:
# [Bí_mật_đêm_Chủ_Nhật_table_01.csv] → Cột tên: ['Người chơi 1']
# [OK] Lưu 9 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bí_mật_đêm_Chủ_Nhật_table_01_artists.csv
# [Bí_mật_đêm_Chủ_Nhật_table_02.csv] → Cột tên: ['Người chơi 1']
# [OK] Lưu 8 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bí_mật_đêm_Chủ_Nhật_table_02_artists.csv
# [Bí_mật_đêm_Chủ_Nhật_table_03.csv] → Cột tên: ['Người chơi 1']
# [OK] Lưu 7 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bí_mật_đêm_Chủ_Nhật_table_03_artists.csv
# [Bước_nhảy_hoàn_vũ_table_01.csv] → Cột tên: ['Cúp bạc']
# [OK] Lưu 8 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_01_artists.csv
# [Bước_nhảy_hoàn_vũ_table_02.csv] → Cột tên: ['Người dẫn']
# [OK] Lưu 10 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_02_artists.csv
# [Bước_nhảy_hoàn_vũ_table_03.csv] → Cột tên: ['Giám khảo']
# [OK] Lưu 22 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_03_artists.csv
# [Bước_nhảy_hoàn_vũ_table_05.csv] → Cột tên: ['Người nổi tiếng']
# [OK] Lưu 14 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_05_artists.csv
# [Bước_nhảy_hoàn_vũ_table_06.csv] → Cột tên: ['Người nổi tiếng']
# [OK] Lưu 8 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_06_artists.csv
# [Bước_nhảy_hoàn_vũ_table_07.csv] → Cột tên: ['Người nổi tiếng']
# [OK] Lưu 7 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_07_artists.csv
# [Bước_nhảy_hoàn_vũ_table_08.csv] → Cột tên: ['Người nổi tiếng']
# [OK] Lưu 6 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_08_artists.csv
# [Bước_nhảy_hoàn_vũ_table_09.csv] → Cột tên: ['Người nổi tiếng']
# [OK] Lưu 3 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_09_artists.csv
# [Bước_nhảy_hoàn_vũ_table_10.csv] → Cột tên: ['Người nổi tiếng']
# [OK] Lưu 10 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_10_artists.csv
# [Bước_nhảy_hoàn_vũ_table_11.csv] → Cột tên: ['Vị trí trong cuộc thi']
# [OK] Lưu 15 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_11_artists.csv
# [Bước_nhảy_hoàn_vũ_table_12.csv] → Cột tên: ['Cặp thí sinh']
# [OK] Lưu 110 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_12_artists.csv
# [Bước_nhảy_hoàn_vũ_table_13.csv] → Cột tên: ['Vũ điệu']
# [OK] Lưu 23 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bước_nhảy_hoàn_vũ_table_13_artists.csv
# [Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_01.csv] → Cột tên: ['Bố']
# [OK] Lưu 4 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_01_artists.csv
# [Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_02.csv] → Cột tên: ['Bố']
# [OK] Lưu 6 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_02_artists.csv
# [Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_03.csv] → Cột tên: ['Bố']
# [OK] Lưu 4 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_03_artists.csv
# [Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_04.csv] → Cột tên: ['Bố']
# [OK] Lưu 4 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_04_artists.csv
# [Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_05.csv] → Cột tên: ['Bố']
# [OK] Lưu 7 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_05_artists.csv
# [Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_06.csv] → Cột tên: ['Năm']
# [OK] Lưu 3 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Bố_ơi_Mình_đi_đâu_thế_chương_trình_truyền_hình_Việt_Nam_table_06_artists.csv
# [Chiến_sĩ_quả_cảm_table_01.csv] → Cột tên: ['Tên nhân vật (Nghệ danh)']
# [OK] Lưu 19 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chiến_sĩ_quả_cảm_table_01_artists.csv
# [Chiến_sĩ_quả_cảm_table_02.csv] → Cột tên: ['Mùa']
# [OK] Lưu 0 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chiến_sĩ_quả_cảm_table_02_artists.csv
# [Chiến_sĩ_quả_cảm_table_03.csv] → Cột tên: ['Đơn vị đồng hành đồng']
# [OK] Lưu 1 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chiến_sĩ_quả_cảm_table_03_artists.csv
# [Chiến_sĩ_quả_cảm_table_04.csv] → Cột tên: ['Năm']
# [OK] Lưu 0 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chiến_sĩ_quả_cảm_table_04_artists.csv
# [Chuyện_ngày_xưa_table_01.csv] → Cột tên: ['Diễn viên tham gia']
# [OK] Lưu 32 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chuyện_ngày_xưa_table_01_artists.csv
# [Chuyện_ngày_xưa_table_02.csv] → Cột tên: ['Diễn viên tham gia']
# [OK] Lưu 10 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chuyện_ngày_xưa_table_02_artists.csv
# [Chọn_ai_đây_table_01.csv] → Cột tên: ['Vòng chơi']
# [OK] Lưu 2 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chọn_ai_đây_table_01_artists.csv
# [Chọn_ai_đây_table_03.csv] → Cột tên: ['Ban bình luận']
# [OK] Lưu 25 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chọn_ai_đây_table_03_artists.csv
# [Chọn_ai_đây_table_04.csv] → Cột tên: ['Cặp 2']
# [OK] Lưu 19 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chọn_ai_đây_table_04_artists.csv
# [Chọn_ai_đây_table_05.csv] → Cột tên: ['Ngày phát sóng']
# [OK] Lưu 15 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chọn_ai_đây_table_05_artists.csv
# [Chọn_ai_đây_table_06.csv] → Cột tên: ['Cặp 1']
# [OK] Lưu 23 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chọn_ai_đây_table_06_artists.csv
# [Chọn_ai_đây_table_07.csv] → Cột tên: ['Cặp 1']
# [OK] Lưu 16 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Chọn_ai_đây_table_07_artists.csv
# [Cặp_đôi_hoàn_hảo_mùa_3_table_01.csv] → Cột tên: ['Bạn diễn']
# [OK] Lưu 7 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Cặp_đôi_hoàn_hảo_mùa_3_table_01_artists.csv
# [Cặp_đôi_hoàn_hảo_mùa_3_table_02.csv] → Cột tên: ['Cặp đôi']
# [OK] Lưu 14 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Cặp_đôi_hoàn_hảo_mùa_3_table_02_artists.csv
# [Cặp_đôi_hoàn_hảo_mùa_3_table_03.csv] → Cột tên: ['Cặp đôi']
# [OK] Lưu 14 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Cặp_đôi_hoàn_hảo_mùa_3_table_03_artists.csv
# [Cặp_đôi_hoàn_hảo_mùa_3_table_04.csv] → Cột tên: ['Cặp đôi']
# [OK] Lưu 14 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Cặp_đôi_hoàn_hảo_mùa_3_table_04_artists.csv
# [Cặp_đôi_hoàn_hảo_mùa_3_table_05.csv] → Cột tên: ['Cặp đôi']
# [OK] Lưu 14 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Cặp_đôi_hoàn_hảo_mùa_3_table_05_artists.csv
# [Cặp_đôi_hoàn_hảo_mùa_3_table_06.csv] → Cột tên: ['Cặp đôi']
# [OK] Lưu 14 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Cặp_đôi_hoàn_hảo_mùa_3_table_06_artists.csv
# [Cặp_đôi_hoàn_hảo_mùa_3_table_07.csv] → Cột tên: ['Cặp đôi']
# [OK] Lưu 14 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Cặp_đôi_hoàn_hảo_mùa_3_table_07_artists.csv
# [Cặp_đôi_hoàn_hảo_mùa_3_table_08.csv] → Cột tên: ['Cặp đôi']
# [OK] Lưu 14 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Cặp_đôi_hoàn_hảo_mùa_3_table_08_artists.csv
# [Cặp_đôi_hoàn_hảo_mùa_3_table_09.csv] → Cột tên: ['Cặp đôi']
# [OK] Lưu 14 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Cặp_đôi_hoàn_hảo_mùa_3_table_09_artists.csv
# [Cặp_đôi_hoàn_hảo_mùa_3_table_10.csv] → Cột tên: ['Cặp đôi']
# [OK] Lưu 14 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Cặp_đôi_hoàn_hảo_mùa_3_table_10_artists.csv
# [Cặp_đôi_hoàn_hảo_mùa_3_table_11.csv] → Cột tên: ['Cặp đôi']
# [OK] Lưu 14 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Cặp_đôi_hoàn_hảo_mùa_3_table_11_artists.csv
# [Gala_cười_table_01.csv] → Cột tên: ['Nghệ sĩ tham gia']
# [OK] Lưu 56 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Gala_cười_table_01_artists.csv
# [Gala_cười_table_02.csv] → Cột tên: ['Diễn viên / nhóm hài do Ban giám khảo bình chọn']
# [OK] Lưu 6 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Gala_cười_table_02_artists.csv
# [Gala_cười_table_03.csv] → Cột tên: ['col_2']
# [OK] Lưu 7 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Gala_cười_table_03_artists.csv
# [Gala_cười_table_04.csv] → Cột tên: ['Diễn viên / nhóm hài được yêu thích do độc giả báo VietNamNet bình chọn']
# [OK] Lưu 9 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Gala_cười_table_04_artists.csv
# [Gala_cười_table_05.csv] → Cột tên: ['Diễn viên / nhóm hài được yêu thích do khán giả bình chọn qua điện thoại']
# [OK] Lưu 2 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Gala_cười_table_05_artists.csv
# [Gương_mặt_thân_quen_table_01.csv] → Cột tên: ['Ban giám khảo']
# [OK] Lưu 13 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Gương_mặt_thân_quen_table_01_artists.csv
# [Gương_mặt_thân_quen_table_02.csv] → Cột tên: ['Mùa']
# [OK] Lưu 0 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Gương_mặt_thân_quen_table_02_artists.csv
# [Gương_mặt_thân_quen_table_03.csv] → Cột tên: ['Nghệ sĩ Việt Nam', 'Nghệ sĩ quốc tế']
# [OK] Lưu 356 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Gương_mặt_thân_quen_table_03_artists.csv
# [Gương_mặt_thân_quen_table_04.csv] → Cột tên: ['Nhà tài trợ']
# [OK] Lưu 1 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Gương_mặt_thân_quen_table_04_artists.csv
# [Gặp_nhau_cuối_năm_table_01.csv] → Cột tên: ['ẩn\nCá nhân']
# [OK] Lưu 81 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Gặp_nhau_cuối_năm_table_01_artists.csv
# [Gặp_nhau_cuối_năm_table_02.csv] → Cột tên: ['(Người) đề cử']
# [OK] Lưu 2 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Gặp_nhau_cuối_năm_table_02_artists.csv
# [Ký_ức_vui_vẻ_table_01.csv] → Cột tên: ['col_4']
# [OK] Lưu 4 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Ký_ức_vui_vẻ_table_01_artists.csv
# [Ký_ức_vui_vẻ_table_03.csv] → Cột tên: ['Thập niên 60']
# [OK] Lưu 13 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Ký_ức_vui_vẻ_table_03_artists.csv
# [Ký_ức_vui_vẻ_table_04.csv] → Cột tên: ['Thập niên 70']
# [OK] Lưu 21 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Ký_ức_vui_vẻ_table_04_artists.csv
# [Ký_ức_vui_vẻ_table_05.csv] → Cột tên: ['Thập niên 70']
# [OK] Lưu 22 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Ký_ức_vui_vẻ_table_05_artists.csv
# [Ký_ức_vui_vẻ_table_06.csv] → Cột tên: ['Thập niên 70']
# [OK] Lưu 13 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Ký_ức_vui_vẻ_table_06_artists.csv
# [Ký_ức_vui_vẻ_table_07.csv] → Cột tên: ['Mùa']
# [OK] Lưu 0 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Ký_ức_vui_vẻ_table_07_artists.csv
# [Ký_ức_vui_vẻ_table_08.csv] → Cột tên: ['Giải thưởng']
# [OK] Lưu 2 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Ký_ức_vui_vẻ_table_08_artists.csv
# [Mái_ấm_gia_đình_Việt_table_01.csv] → Cột tên: ['Ngày phát sóng']
# [OK] Lưu 176 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Mái_ấm_gia_đình_Việt_table_01_artists.csv
# [Mái_ấm_gia_đình_Việt_table_02.csv] → Cột tên: ['Năm']
# [OK] Lưu 1 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Mái_ấm_gia_đình_Việt_table_02_artists.csv
# [Tổ_đội_1_không_2_mùa_1_table_01.csv] → Cột tên: ['Tên']
# [OK] Lưu 6 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Tổ_đội_1_không_2_mùa_1_table_01_artists.csv
# [Tổ_đội_1_không_2_mùa_1_table_02.csv] → Cột tên: ['Ngày phát sóng']
# [OK] Lưu 7 tên vào D:\MangXaHoi\gameshow_vietnam\artists_csv1\Tổ_đội_1_không_2_mùa_1_table_02_artists.csv

# %%
import pandas as pd
from pathlib import Path
import re

# === cấu hình ===
INPUT_DIR = Path(r"D:/MangXaHoi/gameshow_vietnam/artists_csv1")   # chứa các file *_artists.csv
OUTPUT_WIDE = Path(r"D:/MangXaHoi/gameshow_vietnam/all_shows_artists_wide1.csv")
OUTPUT_LONG = Path(r"D:/MangXaHoi/gameshow_vietnam/all_shows_artists_long1.csv")

rows = []
long_records = []

for f in sorted(INPUT_DIR.glob("*.csv")):
    # Lấy tên file, bỏ phần _table... và _artists
    show_name = f.stem
    show_name = re.sub(r"_table.*", "", show_name)   # bỏ từ _table trở đi
    show_name = show_name.replace("_artists", "")    # bỏ hậu tố _artists

    try:
        df = pd.read_csv(f, encoding="utf-8-sig")
    except UnicodeDecodeError:
        df = pd.read_csv(f, encoding="utf-8")

    col = "artist_name" if "artist_name" in df.columns else df.columns[0]
    artists = sorted(set(str(x).strip() for x in df[col].dropna() if str(x).strip()))

    # Dạng dài
    for name in artists:
        long_records.append({"show": show_name, "artist_name": name})

    # Dạng rộng
    row = {"show": show_name}
    for i, name in enumerate(artists, start=1):
        row[f"artist_{i}"] = name
    rows.append(row)

# Xuất dạng rộng
wide_df = pd.DataFrame(rows)
artist_cols = [c for c in wide_df.columns if c.startswith("artist_")]
artist_cols = sorted(artist_cols, key=lambda x: int(x.split("_")[1]))
wide_df = wide_df[["show"] + artist_cols]
wide_df.to_csv(OUTPUT_WIDE, index=False, encoding="utf-8-sig")
print(f"[OK] Xuất dạng rộng → {OUTPUT_WIDE}")

# Xuất dạng dài
if long_records:
    long_df = pd.DataFrame(long_records).sort_values(["show", "artist_name"])
    long_df.to_csv(OUTPUT_LONG, index=False, encoding="utf-8-sig")
    print(f"[OK] Xuất dạng dài → {OUTPUT_LONG}")
# Out:
# [OK] Xuất dạng rộng → D:\MangXaHoi\gameshow_vietnam\all_shows_artists_wide1.csv
# [OK] Xuất dạng dài → D:\MangXaHoi\gameshow_vietnam\all_shows_artists_long1.csv

# %%
import pandas as pd

# File wide
file_path = r"D:/MangXaHoi/gameshow_vietnam/all_shows_artists_wide1.csv"
df = pd.read_csv(file_path, encoding="utf-8-sig")

# Lấy tất cả cột nghệ sĩ
artist_cols = [c for c in df.columns if c.startswith("artist_")]

# Gom tất cả tên nghệ sĩ thành một list
all_artists = []
for col in artist_cols:
    all_artists.extend(df[col].dropna().astype(str).str.strip().tolist())

# Bỏ trùng, bỏ rỗng, sắp xếp
unique_artists = sorted(set(a for a in all_artists if a and a.lower() != "nan"))

# Lưu thành CSV 1 cột
out_file = r"D:/MangXaHoi/gameshow_vietnam/all_unique_artists1.csv"
pd.DataFrame({"artist_name": unique_artists}).to_csv(out_file, index=False, encoding="utf-8-sig")

print(f"Đã lấy {len(unique_artists)} nghệ sĩ duy nhất → {out_file}")
# Out:
# Đã lấy 982 nghệ sĩ duy nhất → D:/MangXaHoi/gameshow_vietnam/all_unique_artists1.csv

# %%
import pandas as pd

df = pd.read_csv(r"D:/MangXaHoi/gameshow_vietnam/all_unique_artists1.csv", encoding="utf-8-sig")

duplicates = df[df.duplicated(subset=["artist_name"], keep=False)]

if not duplicates.empty:
    print("Có nghệ sĩ bị trùng:")
    print(duplicates)
else:
    print("Không có nghệ sĩ nào bị trùng trong file all_unique_artists.csv")
# Out:
# Không có nghệ sĩ nào bị trùng trong file all_unique_artists.csv

# %%
# -*- coding: utf-8 -*-
import re
import time
import json
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import quote

# ================== CẤU HÌNH ==================
INPUT_ARTISTS_CSV = r"D:/MangXaHoi/gameshow_vietnam/all_unique_artists1.csv"  # cột 'artist_name'
OUTPUT_CSV        = r"D:/MangXaHoi/gameshow_vietnam/wiki_infobox_artists1.csv"
LANG              = "vi"   # 'vi' là Wikipedia tiếng Việt
SLEEP_BETWEEN     = 0.8    # nghỉ giữa các request để lịch sự
TIMEOUT           = 20
# ==============================================

WIKI_BASE = f"https://{LANG}.wikipedia.org/wiki/"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; ArtistInfoboxScraper/1.0; +for-academic-use)"
}

def normalize_page_title(name: str) -> str:
    """
    Đưa 'Trấn Thành' -> 'Trấn_Thành' rồi URL-encode.
    Giữ nguyên dấu tiếng Việt, Wikipedia hiểu.
    """ 
    name = (name or "").strip()
    title = name.replace(" ", "_")
    # URL-encode toàn bộ chuỗi (giữ _), để xử lý dấu tiếng Việt đúng
    return quote(title, safe="_")

def fetch_html(url: str) -> str:
    r = requests.get(url, headers=HEADERS, timeout=TIMEOUT)
    if r.status_code == 200:
        return r.text
    # Nếu 404, thử tìm bằng API opensearch để lấy trang gần nhất
    if r.status_code == 404:
        q = url.split("/wiki/")[-1]
        search_q = re.sub(r"_", " ", q)
        api = f"https://{LANG}.wikipedia.org/w/api.php"
        params = {
            "action": "opensearch",
            "search": search_q,
            "limit": 1,
            "namespace": 0,
            "format": "json"
        }
        rs = requests.get(api, params=params, headers=HEADERS, timeout=TIMEOUT)
        if rs.status_code == 200:
            data = rs.json()
            if len(data) >= 4 and data[3]:
                candidate_url = data[3][0]
                rr = requests.get(candidate_url, headers=HEADERS, timeout=TIMEOUT)
                if rr.status_code == 200:
                    return rr.text
    r.raise_for_status()

def clean_text(s: str) -> str:
    s = re.sub(r"\s+", " ", (s or "").strip())
    return s

def parse_infoboxes(html: str) -> dict:
    """
    Trả về dict các trường từ tất cả infobox trên trang (nếu có nhiều, sẽ merge).
    Ưu tiên lấy text trong th/td; nếu có nhiều tr, gộp bằng dấu ' | '.
    """
    soup = BeautifulSoup(html, "html.parser")
    infoboxes = soup.select('[class*="infobox"]')
    result = {}

    for box in infoboxes:
        # Lấy tiêu đề infobox (thường là tên trang)
        caption = box.find("caption")
        if caption:
            result.setdefault("infobox_caption", clean_text(caption.get_text(" ", strip=True)))

        # Duyệt các hàng
        for tr in box.select("tr"):
            # trường hợp cả th và td
            th = tr.find("th")
            td = tr.find("td")

            if th and td:
                key = clean_text(th.get_text(" ", strip=True))
                val = clean_text(td.get_text(" ", strip=True))
                # Chuẩn hóa key (ví dụ đổi về snake_case nhẹ)
                key_norm = re.sub(r"\s+", "_", key.lower())
                # Gộp nếu trùng key
                if key_norm in result and val:
                    result[key_norm] = f"{result[key_norm]} | {val}"
                else:
                    result[key_norm] = val
            # Nếu chỉ có th (dạng header), có thể bỏ qua hoặc lưu riêng
            # elif th and not td:
            #     ...

    return result

def main():
    # 1) Đọc danh sách nghệ sĩ
    artists_df = pd.read_csv(INPUT_ARTISTS_CSV, encoding="utf-8-sig")
    name_col = "artist_name" if "artist_name" in artists_df.columns else artists_df.columns[0]
    artists = [str(x).strip() for x in artists_df[name_col].dropna() if str(x).strip()]

    all_rows = []

    for i, name in enumerate(artists, start=1):
        page_title = normalize_page_title(name)
        url = WIKI_BASE + page_title
        try:
            html = fetch_html(url)
        except Exception as e:
            print(f"[{i}/{len(artists)}] {name}: LỖI tải trang {url} → {e}")
            all_rows.append({"artist_name": name, "wiki_url": url, "error": str(e)})
            time.sleep(SLEEP_BETWEEN)
            continue

        try:
            info = parse_infoboxes(html)
            row = {"artist_name": name, "wiki_url": url}
            # gộp các trường infobox vào dòng
            for k, v in info.items():
                row[k] = v
            all_rows.append(row)
            print(f"[{i}/{len(artists)}] {name}: OK ({len(info)} fields)")
        except Exception as e:
            print(f"[{i}/{len(artists)}] {name}: LỖI parse infobox → {e}")
            all_rows.append({"artist_name": name, "wiki_url": url, "error": f"parse: {e}"})

        time.sleep(SLEEP_BETWEEN)

    # 3) Lưu CSV
    out_df = pd.DataFrame(all_rows)

    # === Thêm ID dựa vào link Wikipedia ===
    import hashlib
    def generate_id(url):
        if pd.isna(url):
            return None
        return hashlib.md5(url.encode('utf-8')).hexdigest()[:8]  # 8 ký tự đầu

    out_df["artist_id"] = out_df["wiki_url"].apply(generate_id)

    # Sắp cột: artist_id, artist_name, wiki_url, infobox_caption, ...
    cols = list(out_df.columns)
    fixed = [c for c in ["artist_id", "artist_name", "wiki_url", "infobox_caption"] if c in cols]
    others = [c for c in cols if c not in fixed]
    out_df = out_df[fixed + others]

    out_df.to_csv(OUTPUT_CSV, index=False, encoding="utf-8-sig")
    print(f"Đã lưu {len(out_df)} nghệ sĩ → {OUTPUT_CSV}")


if __name__ == "__main__":
    main()
# Out:
# [1/982] Adam Levine: OK (9 fields)
# [2/982] Aleksandar Iliev Vachev: LỖI tải trang https://vi.wikipedia.org/wiki/Aleksandar_Iliev_Vachev → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Aleksandar_Iliev_Vachev
# [3/982] Ali Hoàng Dương: LỖI tải trang https://vi.wikipedia.org/wiki/Ali_Ho%C3%A0ng_D%C6%B0%C6%A1ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Ali_Ho%C3%A0ng_D%C6%B0%C6%A1ng
# [4/982] Ali Hoàng Dương Thanh Lam: LỖI tải trang https://vi.wikipedia.org/wiki/Ali_Ho%C3%A0ng_D%C6%B0%C6%A1ng_Thanh_Lam → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/
 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/China_Anne_Mcclain
# [67/982] China Dolls: OK (5 fields)
# [68/982] Chiến Thắng: OK (0 fields)
# [69/982] Chiến Thắng Thu Hương: LỖI tải trang https://vi.wikipedia.org/wiki/Chi%E1%BA%BFn_Th%E1%BA%AFng_Thu_H%C6%B0%C6%A1ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Chi%E1%BA%BFn_Th%E1%BA%AFng_Thu_H%C6%B0%C6%A1ng
# [70/982] Chiều Xuân: OK (12 fields)
# [71/982] Christina Aguilera: OK (12 fields)
# [72/982] Chu Mạnh Cường: LỖI tải trang https://vi.wikipedia.org/wiki/Chu_M%E1%BA%A1nh_C%C6%B0%E1%BB%9Dng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Chu_M%E1%BA%A1nh_C%C6%B0%E1%BB%9Dng
# [73/982] Chubby Checker: OK (9 fields)
# [74/982] Châu Kiệt Luân: OK (19 fields)
# [75/982] Châu Tuyết Vân Phạm Đình: LỖI tải trang https://vi.wikipedia.org/wiki/Ch%C3%A2u_Tuy%E1%BA%BFt_V%C3%A2n_Ph%E1%BA%A1m_%C4%90%C3%ACnh → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Ch%C3%A2u_Tuy%E1%BA%BFt_V%C3%A2n_Ph%E1%BA%A1m_%C4%90%C3%ACnh
# [76/982] Chí Anh: OK (4 fields)
# [77/982] Chí Thiện: OK (0 fields)
# [78/982] Chí Trung: OK (8 fields)
# [79/982] Chí Tài: OK (13 fields)
# [80/982] Chế Hoàng Lan: LỖI tải trang https://vi.wikipedia.org/wiki/Ch%E1%BA%BF_Ho%C3%A0ng_Lan → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Ch%E1%BA%BF_Ho%C3%A0ng_Lan
# [81/982] Chế Linh: OK (18 fields)
# [82/982] Chế Nguyễn Quỳnh Châu Hồ: LỖI tải trang https://vi.wikipedia.org/wiki/Ch%E1%BA%BF_Nguy%E1%BB%85n_Qu%E1%BB%B3nh_Ch%C3%A2u_H%E1%BB%93 → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Ch%E1%BA%BF_Nguy%E1%BB%85n_Qu%E1%BB%B3nh_Ch%C3%A2u_H%E1%BB%93
# [83/982] Cindy Lư: LỖI tải trang https://vi.wikipedia.org/wiki/Cindy_L%C6%B0 → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Cindy_L%C6%B0
# [84/982] Conchita Wurst: OK (4 fields)
# [85/982] Cris Phan: OK (14 fields)
# [86/982] Cung Lâm Na: OK (11 fields)
# [87/982] Cát Phượng: OK (8 fields)
# [88/982] Céline Dion: OK (10 fields)
# [89/982] Công Lý: OK (0 fields)
# [90/982] Công Ninh: OK (9 fields)
# [91/982] Cẩm Ly: OK (17 fields)
# [92/982] Cẩm Vân: OK (0 fields)
# [93/982] Daniel Nikolov Denev: LỖI tải trang https://vi.wikipedia.org/wiki/Daniel_Nikolov_Denev → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Daniel_Nikolov_Denev
# [94/982] Daniela Lujan: LỖI tải trang https://vi.wikipedia.org/wiki/Daniela_Lujan → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Daniela_Lujan
# [95/982] Daniela Nicheva: LỖI tải trang https://vi.wikipedia.org/wiki/Daniela_Nicheva → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Daniela_Nicheva
# [96/982] Declan Galbraith: OK (8 fields)
# [97/982] Dee Trần: LỖI tải trang https://vi.wikipedia.org/wiki/Dee_Tr%E1%BA%A7n → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/
ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/D%C6%B0%C6%A1ng_Thanh_V%C3%A0ng
# [127/982] Dương Triệu Vũ: OK (8 fields)
# [128/982] Elaine Kim Johnston: LỖI tải trang https://vi.wikipedia.org/wiki/Elaine_Kim_Johnston → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Elaine_Kim_Johnston
# [129/982] Elaine Paige: LỖI tải trang https://vi.wikipedia.org/wiki/Elaine_Paige → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Elaine_Paige
# [130/982] Elena Hristova Hadzihristova: LỖI tải trang https://vi.wikipedia.org/wiki/Elena_Hristova_Hadzihristova → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Elena_Hristova_Hadzihristova
# [131/982] Elton John: OK (8 fields)
# [132/982] Elvis Phương: OK (17 fields)
# [133/982] Elvis Presley: OK (22 fields)
# [134/982] Emma Nhất Khanh: LỖI tải trang https://vi.wikipedia.org/wiki/Emma_Nh%E1%BA%A5t_Khanh → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Emma_Nh%E1%BA%A5t_Khanh
# [135/982] Engelbert Humperdinck: LỖI tải trang https://vi.wikipedia.org/wiki/Engelbert_Humperdinck → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Engelbert_Humperdinck
# [136/982] Eve Kdi: OK (0 fields)
# [137/982] Evgeni Lyubomirov Popov: LỖI tải trang https://vi.wikipedia.org/wiki/Evgeni_Lyubomirov_Popov → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Evgeni_Lyubomirov_Popov
# [138/982] Fami Canxi: LỖI tải trang https://vi.wikipedia.org/wiki/Fami_Canxi → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Fami_Canxi
# [139/982] Fools Garden: OK (8 fields)
# [140/982] France Gall: OK (8 fields)
# [141/982] Freddie Mercury: OK (16 fields)
# [142/982] George Ganev: OK (16 fields)
# [143/982] George Michael: OK (8 fields)
# [144/982] Georgi Dimov: OK (4 fields)
# [145/982] Georgi Ganev: OK (5 fields)
# [146/982] Georgi Naidenov: LỖI tải trang https://vi.wikipedia.org/wiki/Georgi_Naidenov → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Georgi_Naidenov
# [147/982] Gerard Darmon: LỖI tải trang https://vi.wikipedia.org/wiki/Gerard_Darmon → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Gerard_Darmon
# [148/982] Giang Châu: OK (0 fields)
# [149/982] Giang Còi: OK (15 fields)
# [150/982] Giao Linh: OK (8 fields)
# [151/982] Gin Tuấn Kiệt: OK (10 fields)
# [152/982] Giải Mai Vàng: OK (7 fields)
# [153/982] Gloria Gaynor: OK (8 fields)
# [154/982] Hamlet Trương Hiền Mai: LỖI tải trang https://vi.wikipedia.org/wiki/Hamlet_Tr%C6%B0%C6%A1ng_Hi%E1%BB%81n_Mai → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Hamlet_Tr%C6%B0%C6%A1ng_Hi%E1%BB%81n_Mai
# [155/982] Hari Won: OK (16 fields)
# [156/982] Hen Niê: OK (12 fields)
# [157/982] Henry Lau: OK (20 fields)
# [158/982] Hiếu Hiền: OK (16 fields)
# [159/982] Hiền Mai: OK (7 fields)
# [160/982] Hiền Thục: OK (9 fields)
# [161/982] Hiệp Gà: OK (13 fields)
# [162/982] Hoài Linh: OK (12 fields)
# [163/982] Hoài Lâm: OK (15 fields)
# [164/982] Hoàng Bách: OK (5 fields)
# [165/982] Hoàng Bách Lệ Hằng: LỖI tải trang https://vi.wikipedia.org/wiki/Ho%C3%A0ng_B%C3%A1ch_L%E1%BB%87_H%E1%BA%B1ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Ho%C3%A0ng
→ 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Ina_Chokova
# [257/982] Ira Maya Sopha: LỖI tải trang https://vi.wikipedia.org/wiki/Ira_Maya_Sopha → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Ira_Maya_Sopha
# [258/982] Isaac Mie: OK (15 fields)
# [259/982] Iva Ludmilova Grigorova: LỖI tải trang https://vi.wikipedia.org/wiki/Iva_Ludmilova_Grigorova → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Iva_Ludmilova_Grigorova
# [260/982] Ivan Kirilov Spasov: LỖI tải trang https://vi.wikipedia.org/wiki/Ivan_Kirilov_Spasov → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Ivan_Kirilov_Spasov
# [261/982] Ivan Nedyalkov Raykov: LỖI tải trang https://vi.wikipedia.org/wiki/Ivan_Nedyalkov_Raykov → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Ivan_Nedyalkov_Raykov
# [262/982] Jaden Smith: OK (9 fields)
# [263/982] James Brown: OK (10 fields)
# [264/982] Janet Jackson: OK (9 fields)
# [265/982] Jang Mi Quang Đăng: LỖI tải trang https://vi.wikipedia.org/wiki/Jang_Mi_Quang_%C4%90%C4%83ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Jang_Mi_Quang_%C4%90%C4%83ng
# [266/982] Jaykii Thu Quỳnh: LỖI tải trang https://vi.wikipedia.org/wiki/Jaykii_Thu_Qu%E1%BB%B3nh → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Jaykii_Thu_Qu%E1%BB%B3nh
# [267/982] Jemma Rix: OK (3 fields)
# [268/982] Jennifer Holliday: LỖI tải trang https://vi.wikipedia.org/wiki/Jennifer_Holliday → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Jennifer_Holliday
# [269/982] Jennifer Lopez: OK (12 fields)
# [270/982] Jennifer Phạm: OK (12 fields)
# [271/982] Jim Carrey: OK (8 fields)
# [272/982] Jimii Nguyễn: LỖI tải trang https://vi.wikipedia.org/wiki/Jimii_Nguy%E1%BB%85n → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Jimii_Nguy%E1%BB%85n
# [273/982] Joan Jett: OK (10 fields)
# [274/982] John Huy Trần: LỖI tải trang https://vi.wikipedia.org/wiki/John_Huy_Tr%E1%BA%A7n → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/John_Huy_Tr%E1%BA%A7n
# [275/982] Josh Groban: OK (8 fields)
# [276/982] Jun Phạm: OK (14 fields)
# [277/982] Jun Vũ: OK (9 fields)
# [278/982] Justin Bieber: OK (11 fields)
# [279/982] Justin Timberlake: OK (6 fields)
# [280/982] Karen Carpenter: OK (10 fields)
# [281/982] Kasim Hoàng Vũ: OK (17 fields)
# [282/982] Katherine Jenkins: LỖI tải trang https://vi.wikipedia.org/wiki/Katherine_Jenkins → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Katherine_Jenkins
# [283/982] Katrina Kaif: OK (7 fields)
# [284/982] Katy Perry: OK (14 fields)
# [285/982] Kay Trần: OK (10 fields)
# [286/982] Kha Ly Hồ Quang Hiếu: LỖI tải trang https://vi.wikipedia.org/wiki/Kha_Ly_H%E1%BB%93_Quang_Hi%E1%BA%BFu → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Kha_Ly_H%E1%BB%93_Quang_Hi%E1%BA%BFu
# [287/982] Khánh Hà: OK (0 fields)
# [288/982] Khánh Linh: OK (4 fields)
# [289/982] Khánh Ly: OK (6 fields)
# [290/982] Khánh My: OK (5 fields)
# [291/982] Khánh Nam: OK (11 fields)
# [292/982] Khánh Ninh Dương Lan Ngọc: LỖI tải trang https://vi.wikipedia.org/wiki/Kh%C3%A1nh_Ninh_D%C6%B0%C6%A1ng_Lan_Ng%E1%BB%8Dc → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Kh%C3%A1nh_Ninh_D%C6%B0%C6%A1ng_Lan_Ng%E1%BB%8Dc
# [293/982] Khánh Phương: OK (9 fields)
# [294/982] Khánh Thi: OK (9 fields)
# [295/982] Khánh Vân Trương Đình Hoàng: LỖI tải trang https://vi.wikipedia.org/wiki/Kh%C3%A1nh_V%C3%A2n_Tr%C6%B0%C6%A1ng_%C4%90%C3%ACnh_Ho%C3%A0ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Kh%C3%A1nh_V%C3%A2n_Tr%C6%B0%C6%A1ng_%C4%90%C3%ACnh_Ho%C3%A0ng
# [296/982] Khánh Đặng: LỖI tải trang https://vi.wikipedia.org/wiki/Kh%C3%A1nh_%C4%90%E1%BA%B7ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Kh%C3%A1nh_%C4%90%E1%BA%B7ng
# [297/982] Khả Ngân: OK (8 fields)
# [298/982] Khả Như: OK (8 fields)
# [299/982] Khắc Triệu: LỖI tải trang https://vi.wikipedia.org/wiki/Kh%E1%BA%AFc_Tri%E1%BB%87u → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Kh%E1%BA%AFc_Tri%E1%BB%87u
# [300/982] Khổng Tú Quỳnh Minh Dự: LỖI tải trang https://vi.wikipedia.org/wiki/Kh%E1%BB%95ng_T%C3%BA_Qu%E1%BB%B3nh_Minh_D%E1%BB%B1 → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Kh%E1%BB%95ng_T%C3%BA_Qu%E1%BB%B3nh_Minh_D%E1%BB%B1
# [301/982] Khởi My: OK (12 fields)
# [302/982] Kim Hiền: OK (8 fields)
# [303/982] Kim Huyền: OK (13 fields)
# [304/982] Kim Ngọc: OK (9 fields)
# [305/982] Kim Oanh: OK (0 fields)
# [306/982] Kim Phương: LỖI tải trang https://vi.wikipedia.org/wiki/Kim_Ph%C6%B0%C6%A1ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Kim_Ph%C6%B0%C6%A1ng
# [307/982] Kim Tuyến Võ Tấn Phát: LỖI tải trang https://vi.wikipedia.org/wiki/Kim_Tuy%E1%BA%BFn_V%C3%B5_T%E1%BA%A5n_Ph%C3%A1t → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Kim_Tuy%E1%BA%BFn_V%C3%B5_T%E1%BA%A5n_Ph%C3%A1t
# [308/982] Kim Tử Long: OK (7 fields)
# [309/982] Kim Tử Long Cát Phượng: LỖI tải trang https://vi.wikipedia.org/wiki/Kim_T%E1%BB%AD_Long_C%C3%A1t_Ph%C6%B0%E1%BB%A3ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Kim_T%E1%BB%AD_Long_C%C3%A1t_Ph%C6%B0%E1%BB%A3ng
# [310/982] Kim Xuyến: OK (12 fields)
# [311/982] Kim Xuân: OK (14 fields)
# [312/982] Kiril Dimov: LỖI tải trang https://vi.wikipedia.org/wiki/Kiril_Dimov → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Kiril_Dimov
# [313/982] Kiều Mai Lý: OK (10 fields)
# [314/982] Kiều Minh Tuấn: OK (9 fields)
# [315/982] Kiều Minh Tuấn Hòa Minzy: LỖI tải trang https://vi.wikipedia.org/wiki/Ki%E1%BB%81u_Minh_Tu%E1%BA%A5n_H%C3%B2a_Minzy → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/
 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/L%C6%B0u_Huy%E1%BB%81n_Trang
# [375/982] Lưu Mạnh Dũng: LỖI tải trang https://vi.wikipedia.org/wiki/L%C6%B0u_M%E1%BA%A1nh_D%C5%A9ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/L%C6%B0u_M%E1%BA%A1nh_D%C5%A9ng
# [376/982] Lưu Đức Hoa: OK (10 fields)
# [377/982] Lương Bích Hữu: OK (11 fields)
# [378/982] Lương Chí Diễn: LỖI tải trang https://vi.wikipedia.org/wiki/L%C6%B0%C6%A1ng_Ch%C3%AD_Di%E1%BB%85n → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/L%C6%B0%C6%A1ng_Ch%C3%AD_Di%E1%BB%85n
# [379/982] Lương Mạnh Hải: OK (5 fields)
# [380/982] Lương Mỹ: LỖI tải trang https://vi.wikipedia.org/wiki/L%C6%B0%C6%A1ng_M%E1%BB%B9 → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/L%C6%B0%C6%A1ng_M%E1%BB%B9
# [381/982] Lại Phú Đôn: OK (16 fields)
# [382/982] Lại Văn Sâm: OK (8 fields)
# [383/982] Lệ Quyên: OK (0 fields)
# [384/982] Lệ Thủy: OK (21 fields)
# [385/982] Lọ Lem: OK (3 fields)
# [386/982] Ma Ran Đô Nguyễn Duyên: LỖI tải trang https://vi.wikipedia.org/wiki/Ma_Ran_%C4%90%C3%B4_Nguy%E1%BB%85n_Duy%C3%AAn → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Ma_Ran_%C4%90%C3%B4_Nguy%E1%BB%85n_Duy%C3%AAn
# [387/982] Madhuri Dixit: OK (14 fields)
# [388/982] Mai Lê: OK (0 fields)
# [389/982] Mai Nguyễn Thanh Phương: OK (15 fields)
# [390/982] Mai Phượng: OK (0 fields)
# [391/982] Mai Sơn: OK (19 fields)
# [392/982] Mai Thanh Hà Nguyễn Trần: LỖI tải trang https://vi.wikipedia.org/wiki/Mai_Thanh_H%C3%A0_Nguy%E1%BB%85n_Tr%E1%BA%A7n → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Mai_Thanh_H%C3%A0_Nguy%E1%BB%85n_Tr%E1%BA%A7n
# [393/982] Mai Tuyết Hoa: LỖI tải trang https://vi.wikipedia.org/wiki/Mai_Tuy%E1%BA%BFt_Hoa → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Mai_Tuy%E1%BA%BFt_Hoa
# [394/982] Marc Anthony: OK (20 fields)
# [395/982] Mariah Carey: OK (10 fields)
# [396/982] Marilyn Monroe: OK (11 fields)
# [397/982] Mario Maurer: OK (10 fields)
# [398/982] Mathe Altery: LỖI tải trang https://vi.wikipedia.org/wiki/Mathe_Altery → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Mathe_Altery
# [399/982] Mayumi Itsuwa: OK (6 fields)
# [400/982] Michael Buble: OK (7 fields)
# [401/982] Michael Jackson: OK (16 fields)
# [402/982] Mihaela Pavlova: LỖI tải trang https://vi.wikipedia.org/wiki/Mihaela_Pavlova → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Mihaela_Pavlova
# [403/982] Minh An: OK (0 fields)
# [404/982] Minh Béo: OK (7 fields)
# [405/982] Minh Gái: LỖI tải trang https://vi.wikipedia.org/wiki/Minh_G%C3%A1i → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Minh_G%C3%A1i
# [406/982] Minh Hoà: LỖI tải trang https://vi.wikipedia.org/wiki/Minh_Ho%C3%A0 → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Minh_Ho%C3%A0
# [407/982] Minh Hoàng: OK (12 fields)
# [408/982] Minh Hằng: OK (13 fields)
# [409/982] Minh Hằng Atanas Dimitrov Stoyanov: LỖI tải trang https://vi.wikipedia.org/wiki/Minh_H%E1%BA%B1ng_Atanas_Dimitrov_Stoyanov → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Minh_H%E1%BA%B1ng_Atanas_Dimitrov_Stoyanov
# [410/982] Minh Khang: OK (12 fields)
# [411/982] Minh Luân Phương Thanh: LỖI tải trang https://vi.wikipedia.org/wiki/Minh_Lu%C3%A2n_Ph%C6%B0%C6%A1ng_Thanh → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Minh_Lu%C3%A2n_Ph%C6%B0%C6%A1ng_Thanh
# [412/982] Minh Nhí: OK (11 fields)
# [413/982] Minh Phương: OK (11 fields)
# [414/982] Minh Phượng: OK (10 fields)
# [415/982] Minh Quân: OK (11 fields)
# [416/982] Minh Thuận: OK (0 fields)
# [417/982] Minh Thư: OK (0 fields)
# [418/982] Minh Tiến: OK (0 fields)
# [419/982] Minh Trang: OK (7 fields)
# [420/982] Minh Triệu Minh Vương: LỖI tải trang https://vi.wikipedia.org/wiki/Minh_Tri%E1%BB%87u_Minh_V%C6%B0%C6%A1ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Minh_Tri%E1%BB%87u_Minh_V%C6%B0%C6%A1ng
# [421/982] Minh Trung: OK (7 fields)
# [422/982] Minh Tuyết: OK (8 fields)
# [423/982] Minh Tít: LỖI tải trang https://vi.wikipedia.org/wiki/Minh_T%C3%ADt → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Minh_T%C3%ADt
# [424/982] Minh Tú Quang Anh: LỖI tải trang https://vi.wikipedia.org/wiki/Minh_T%C3%BA_Quang_Anh → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Minh_T%C3%BA_Quang_Anh
# [425/982] Minh Vương: OK (17 fields)
# [426/982] Minh Vượng: OK (11 fields)
# [427/982] Minh Đức: OK (0 fields)
# [428/982] Miu Lê: OK (11 fields)
# [429/982] Mobifone Nguyễn Kim: LỖI tải trang https://vi.wikipedia.org/wiki/Mobifone_Nguy%E1%BB%85n_Kim → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/Mobifone_Nguy%E1%BB%85n_Kim
# [430/982] Modern Talking: OK (5 fields)
# [431/982] Măng Thị Hội: LỖI tải trang https://vi.wikipedia.org/wiki/M%C4%83ng_Th%E1%BB%8B_H%E1%BB%99i → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/M%C4%83ng_Th%E1%BB%8B_H%E1%BB%99i
# [432/982] Mạc Văn Khoa: OK (10 fields)
# [433/982] Mạc Văn Khoa Thanh Thúy: LỖI tải trang https://vi.wikipedia.org/wiki/M%E1%BA%A1c_V%C4%83n_Khoa_Thanh_Th%C3%BAy → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/M%E1%BA%A1c_V%C4%83n_Khoa_Thanh_Th%C3%BAy
# [434/982] Mạnh Dung: OK (17 fields)
# [435/982] Mạnh Dũng: LỖI tải trang https://vi.wikipedia.org/wiki/M%E1%BA%A1nh_D%C5%A9ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/M%E1%BA%A1nh_D%C5%A9ng
# [436/982] Mạnh Hưng: OK (10 fields)
# [437/982] Mạnh Quỳnh: OK (6 fields)
# [438/982] Mạnh Trường: OK (14 fields)
# [439/982] Mỹ Dung: LỖI tải trang https://vi.wikipedia.org/wiki/M%E1%BB%B9_Dung → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki
 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/V%C3%A2n_Kh%C3%A1nh_Anh_T%C3%A0i
# [882/982] Vân Quyền: LỖI tải trang https://vi.wikipedia.org/wiki/V%C3%A2n_Quy%E1%BB%81n → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/V%C3%A2n_Quy%E1%BB%81n
# [883/982] Vân Sơn: OK (0 fields)
# [884/982] Vân Trang: OK (9 fields)
# [885/982] Vòng đặc: LỖI tải trang https://vi.wikipedia.org/wiki/V%C3%B2ng_%C4%91%E1%BA%B7c → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/V%C3%B2ng_%C4%91%E1%BA%B7c
# [886/982] Vòng đối đầu: LỖI tải trang https://vi.wikipedia.org/wiki/V%C3%B2ng_%C4%91%E1%BB%91i_%C4%91%E1%BA%A7u → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/V%C3%B2ng_%C4%91%E1%BB%91i_%C4%91%E1%BA%A7u
# [887/982] Võ Hoàng Yến: OK (14 fields)
# [888/982] Võ Hoàng Yến Hải Nam: LỖI tải trang https://vi.wikipedia.org/wiki/V%C3%B5_Ho%C3%A0ng_Y%E1%BA%BFn_H%E1%BA%A3i_Nam → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/V%C3%B5_Ho%C3%A0ng_Y%E1%BA%BFn_H%E1%BA%A3i_Nam
# [889/982] Võ Minh Lâm Mai Anh: LỖI tải trang https://vi.wikipedia.org/wiki/V%C3%B5_Minh_L%C3%A2m_Mai_Anh → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/V%C3%B5_Minh_L%C3%A2m_Mai_Anh
# [890/982] Võ Nam Trung: LỖI tải trang https://vi.wikipedia.org/wiki/V%C3%B5_Nam_Trung → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/V%C3%B5_Nam_Trung
# [891/982] Võ Thành Trung: OK (10 fields)
# [892/982] Võ Thành Tâm: OK (12 fields)
# [893/982] Võ Tấn Phát: OK (9 fields)
# [894/982] Võ Đăng Khoa: LỖI tải trang https://vi.wikipedia.org/wiki/V%C3%B5_%C4%90%C4%83ng_Khoa → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/V%C3%B5_%C4%90%C4%83ng_Khoa
# [895/982] Văn Chương: OK (0 fields)
# [896/982] Văn Hiệp: OK (17 fields)
# [897/982] Văn Hường: OK (13 fields)
# [898/982] Văn Mai Hương: OK (9 fields)
# [899/982] Vũ Cát Tường: OK (13 fields)
# [900/982] Vũ Hoàng Điệp: OK (9 fields)
# [901/982] Vũ Hà: OK (0 fields)
# [902/982] Vũ Linh: OK (0 fields)
# [903/982] Vũ Luân: OK (12 fields)
# [904/982] Vũ Minh: OK (0 fields)
# [905/982] Vũ Mạnh Cường: OK (0 fields)
# [906/982] Vũ Mạnh Cường Anh Thi: LỖI tải trang https://vi.wikipedia.org/wiki/V%C5%A9_M%E1%BA%A1nh_C%C6%B0%E1%BB%9Dng_Anh_Thi → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/V%C5%A9_M%E1%BA%A1nh_C%C6%B0%E1%BB%9Dng_Anh_Thi
# [907/982] Vũ Ngọc Anh: OK (13 fields)
# [908/982] Vũ Thu Phương: OK (13 fields)
# [909/982] Vũ Thu Phương Erik: LỖI tải trang https://vi.wikipedia.org/wiki/V%C5%A9_Thu_Ph%C6%B0%C6%A1ng_Erik → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/V%C5%A9_Thu_Ph%C6%B0%C6%A1ng_Erik
# [910/982] Vương Hồng Đào: LỖI tải trang https://vi.wikipedia.org/wiki/V%C6%B0%C6%A1ng_H%E1%BB%93ng_%C4%90%C3%A0o → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/V%
ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/%C4%90%E1%BA%B7ng_Thu_H%C6%B0%C6%A1ng
# [962/982] Đỗ Duy Nam: OK (10 fields)
# [963/982] Đỗ Duy Nam Ngọc Huyền: LỖI tải trang https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Duy_Nam_Ng%E1%BB%8Dc_Huy%E1%BB%81n → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Duy_Nam_Ng%E1%BB%8Dc_Huy%E1%BB%81n
# [964/982] Đỗ Hoàng Hiệp Lương Thu: LỖI tải trang https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Ho%C3%A0ng_Hi%E1%BB%87p_L%C6%B0%C6%A1ng_Thu → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Ho%C3%A0ng_Hi%E1%BB%87p_L%C6%B0%C6%A1ng_Thu
# [965/982] Đỗ Long Vũ Thúy Quỳnh: LỖI tải trang https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Long_V%C5%A9_Th%C3%BAy_Qu%E1%BB%B3nh → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Long_V%C5%A9_Th%C3%BAy_Qu%E1%BB%B3nh
# [966/982] Đỗ Minh: LỖI tải trang https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Minh → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Minh
# [967/982] Đỗ Quang Đăng: LỖI tải trang https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Quang_%C4%90%C4%83ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_Quang_%C4%90%C4%83ng
# [968/982] Đới Anh Quân: LỖI tải trang https://vi.wikipedia.org/wiki/%C4%90%E1%BB%9Bi_Anh_Qu%C3%A2n → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%9Bi_Anh_Qu%C3%A2n
# [969/982] Đức Anh: LỖI tải trang https://vi.wikipedia.org/wiki/%C4%90%E1%BB%A9c_Anh → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%A9c_Anh
# [970/982] Đức Châu: OK (0 fields)
# [971/982] Đức Hiệp: OK (11 fields)
# [972/982] Đức Huy: OK (8 fields)
# [973/982] Đức Hùng: OK (11 fields)
# [974/982] Đức Hải: OK (0 fields)
# [975/982] Đức Khuê: OK (15 fields)
# [976/982] Đức Khuê Thanh Hằng: LỖI tải trang https://vi.wikipedia.org/wiki/%C4%90%E1%BB%A9c_Khu%C3%AA_Thanh_H%E1%BA%B1ng → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/%C4%90%E1%BB%A9c_Khu%C3%AA_Thanh_H%E1%BA%B1ng
# [977/982] Đức Phúc: OK (7 fields)
# [978/982] Đức Thịnh: OK (0 fields)
# [979/982] Đức Tuấn: OK (5 fields)
# [980/982] Ưng Hoàng Phúc: OK (10 fields)
# [981/982] Ưng Hoàng Phúc Thùy Trang: LỖI tải trang https://vi.wikipedia.org/wiki/%C6%AFng_Ho%C3%A0ng_Ph%C3%BAc_Th%C3%B9y_Trang → 404 Client Error: Not Found for url: https://vi.wikipedia.org/wiki/%C6%AFng_Ho%C3%A0ng_Ph%C3%BAc_Th%C3%B9y_Trang
# [982/982] Ốc Thanh Vân: OK (8 fields)
# Đã lưu 982 nghệ sĩ → D:/MangXaHoi/gameshow_vietnam/wiki_infobox_artists1.csv

# %%
import pandas as pd

# File đầu vào
INPUT = r"D:/MangXaHoi/gameshow_vietnam/wiki_infobox_artists1.csv"
WITH_DATA = r"D:/MangXaHoi/gameshow_vietnam/artists_with_data1.csv"
NO_DATA   = r"D:/MangXaHoi/gameshow_vietnam/artists_no_data1.csv"

# Đọc file
df = pd.read_csv(INPUT, encoding="utf-8-sig")

# Lấy tất cả cột xuất hiện sau wiki_url
if "wiki_url" in df.columns:
    cols_after_url = df.columns[df.columns.get_loc("error")+1:]
else:
    raise ValueError("Không tìm thấy cột 'wiki_url' trong file.")

# Chia nhóm
with_data = df[df[cols_after_url].notna().any(axis=1)]   # có ít nhất 1 dữ liệu
no_data   = df[~df.index.isin(with_data.index)]          # toàn bộ trống

# Xuất file
with_data.to_csv(WITH_DATA, index=False, encoding="utf-8-sig")
no_data.to_csv(NO_DATA, index=False, encoding="utf-8-sig")

print(f"Có dữ liệu: {len(with_data)} nghệ sĩ → {WITH_DATA}")
print(f"Không có dữ liệu: {len(no_data)} nghệ sĩ → {NO_DATA}")
# Out:
# Có dữ liệu: 458 nghệ sĩ → D:/MangXaHoi/gameshow_vietnam/artists_with_data1.csv
# Không có dữ liệu: 524 nghệ sĩ → D:/MangXaHoi/gameshow_vietnam/artists_no_data1.csv

# %%
import pandas as pd

# Đường dẫn 2 file CSV
file1 = r"D:/MangXaHoi/gameshow_vietnam/all_shows_artists_long1.csv"
file2 = r"D:/MangXaHoi/gameshow_vietnam/all_shows_artists_long.csv"

# Đọc dữ liệu
df1 = pd.read_csv(file1, encoding="utf-8-sig")
df2 = pd.read_csv(file2, encoding="utf-8-sig")

# Gộp lại
merged = pd.concat([df1, df2], ignore_index=True)

# Lưu ra file mới
output = r"D:/MangXaHoi/gameshow_vietnam/merge_all_shows_artists_long.csv"
merged.to_csv(output, index=False, encoding="utf-8-sig")

print(f"Đã gộp {len(df1)} + {len(df2)} = {len(merged)} dòng vào: {output}")
# Out:
# Đã gộp 1395 + 1301 = 2696 dòng vào: D:/MangXaHoi/gameshow_vietnam/merge_all_shows_artists_long.csv

# %%
# Đọc file all_shows_artists_long.csv để làm ground truth
long_file = r"D:/MangXaHoi/gameshow_vietnam/merge_all_shows_artists_long.csv"
long_df = pd.read_csv(long_file, encoding="utf-8-sig")

# Tạo ground truth: mỗi nghệ sĩ gán với gameshow đầu tiên mà họ tham gia
ground_truth = {}
for artist, group in long_df.groupby("artist_name"):
    shows = group["show"].tolist()
    if shows:
        ground_truth[artist] = shows[0]   # lấy gameshow đầu tiên làm nhãn

# %%
import pandas as pd

df = pd.read_csv(r"D:/MangXaHoi/gameshow_vietnam/merge_artists_with_data.csv", encoding="utf-8-sig")

duplicates = df[df.duplicated(subset=["artist_name"], keep=False)]

if not duplicates.empty:
    print("Có nghệ sĩ bị trùng:")
    print(duplicates)
else:
    print("Không có nghệ sĩ nào bị trùng trong file all_unique_artists.csv")
# Out:
# Có nghệ sĩ bị trùng:
#     artist_id          artist_name  \
# 0    572d005d  Angela Phương Trinh
# 2    09ba692c              Anh Thư
# 3    6759faeb              Anh Đức
# 13   74af5de5          Bích Phương
# 16   b283a223            Bạch Long
# ..        ...                  ...
# 808  ca156656           Đỗ Duy Nam
# 811  c3ba25c2             Đức Hùng
# 812  43070099             Đức Phúc
# 813  c4f1cb42       Ưng Hoàng Phúc
# 814  897526cc         Ốc Thanh Vân
#
#                                               wiki_url infobox_caption  \
# 0    https://vi.wikipedia.org/wiki/Angela_Ph%C6%B0%...             NaN
# 2           https://vi.wikipedia.org/wiki/Anh_Th%C6%B0             NaN
# 3    https://vi.wikipedia.org/wiki/Anh_%C4%90%E1%BB...             NaN
# 13   https://vi.wikipedia.org/wiki/B%C3%ADch_Ph%C6%...             NaN
# 16     https://vi.wikipedia.org/wiki/B%E1%BA%A1ch_Long             NaN
# ..                                                 ...             ...
# 808  https://vi.wikipedia.org/wiki/%C4%90%E1%BB%97_...             NaN
# 811  https://vi.wikipedia.org/wiki/%C4%90%E1%BB%A9c...   Nghệ sĩ ưu tú
# 812  https://vi.wikipedia.org/wiki/%C4%90%E1%BB%A9c...             NaN
# 813  https://vi.wikipedia.org/wiki/%C6%AFng_Ho%C3%A...             NaN
# 814  https://vi.wikipedia.org/wiki/%E1%BB%90c_Thanh...             NaN
#
#     tên_khai_sinh                                               sinh hôn_nhân  \
# 0             NaN  Lê Ngọc Phương Trinh 8 tháng 2, 1995 (30 tuổi)...      NaN
# 2             NaN  Nguyễn Thị Anh Thư 26 tháng 4, 1982 (43 tuổi) ...      NaN
# 3      Bùi Đức Ái                                                NaN      NaN
# 13            NaN  Bùi Thị Bích Phương 30 tháng 9, 1989 (36 tuổi)...      NaN
# 16            NaN                                                NaN      NaN
# ..            ...                                                ...      ...
# 808           NaN  8 tháng 6, 1990 (35 tuổi) Bắc Hà , Lào Cai , V...      NaN
# 811           NaN                                                NaN      NaN
# 812           NaN  Nguyễn Đức Phúc 15 tháng 10, 1996 (28 tuổi) Hà...      NaN
# 813           NaN  Nguyễn Quốc Thanh 18 tháng 8, 1981 (44 tuổi) K...      NaN
# 814           NaN  Phạm Thị Thanh Vân 18 tháng 2, 1984 (41 tuổi) ...      NaN
#
#                                            nghề_nghiệp  \
# 0                            Ca sĩ Diễn viên Người mẫu
# 2                                  Người mẫu Diễn viên
# 3                                              Nhà văn
# 13                                               Ca sĩ
# 16                                                 NaN
# ..                                                 ...
# 808         Diễn viên Nghệ sĩ hài Nhân vật truyền hình
# 811  Nghệ sĩ sân khấu, diễn viên , Nhà thiết kế thờ...
# 812                             Ca sĩ diễn viên rapper
# 813                            Ca sĩ Diễn viên Vũ công
# 814                   Diễn viên Người dẫn chương trình
#
#                                  thể_loại    nhạc_cụ  ... vùng_thuộc_bang  \
# 0                                     NaN        NaN  ...             NaN
# 2                                     NaN        NaN  ...             NaN
# 3                                     NaN        NaN  ...             NaN
# 13   V-pop R&B ballad dance-pop disco EDM  Giọng hát  ...             NaN
# 16                                    NaN        NaN  ...             NaN
# ..                                    ...        ...  ...             ...
# 808                                   NaN        NaN  ...             NaN
# 811                                   NaN        NaN  ...             NaN
# 812        V-pop R&B Dance-pop EDM Ballad  Giọng hát  ...             NaN
# 813                      V-pop R&B ballad  Giọng hát  ...             NaN
# 814                                   NaN        NaN  ...             NaN
#
#     tiểu_vùng quỳnh_lương_vị_trí_xã_quỳnh_lương_trên_bản_đồ_việt_nam  \
# 0         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 13        NaN                                                NaN
# 16        NaN                                                NaN
# ..        ...                                                ...
# 808       NaN                                                NaN
# 811       NaN                                                NaN
# 812       NaN                                                NaN
# 813       NaN                                                NaN
# 814       NaN                                                NaN
#
#      sơn_lương_vị_trí_xã_sơn_lương_trên_bản_đồ_việt_nam  \
# 0                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 13                                                 NaN
# 16                                                 NaN
# ..                                                 ...
# 808                                                NaN
# 811                                                NaN
# 812                                                NaN
# 813                                                NaN
# 814                                                NaN
#
#     trân_châu_vị_trí_xã_trân_châu_trên_bản_đồ_việt_nam bản_đồ_xã_tùng_lâm  \
# 0                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 13                                                 NaN                NaN
# 16                                                 NaN                NaN
# ..                                                 ...                ...
# 808                                                NaN                NaN
# 811                                                NaN                NaN
# 812                                                NaN                NaN
# 813                                                NaN                NaN
# 814                                                NaN                NaN
#
#      đỉnh_cao_nhất điểm_dân_cư_lớn_nhất dân_số giải_thưởng_nổi_bật
# 0              NaN                  NaN    NaN                 NaN
# 2              NaN                  NaN    NaN                 NaN
# 3              NaN                  NaN    NaN                 NaN
# 13             NaN                  NaN    NaN                 NaN
# 16             NaN                  NaN    NaN                 NaN
# ..             ...                  ...    ...                 ...
# 808            NaN                  NaN    NaN                 NaN
# 811            NaN                  NaN    NaN                 NaN
# 812            NaN                  NaN    NaN                 NaN
# 813            NaN                  NaN    NaN                 NaN
# 814            NaN                  NaN    NaN                 NaN
#
# [280 rows x 536 columns]

# %%
import pandas as pd

# ===== Đường dẫn =====
WITH_ARTISTS = r"D:/MangXaHoi/gameshow_vietnam/merge_artists_with_data.csv"      # cột: artist_name
LONG_FILE    = r"D:/MangXaHoi/gameshow_vietnam/merge_all_shows_artists_long.csv" # cột: show, artist_name
OUT_MATRIX   = r"D:/MangXaHoi/gameshow_vietnam/artist_coappearance_matrix1.csv"
# =====================

# Đọc dữ liệu
with_df = pd.read_csv(WITH_ARTISTS, encoding="utf-8-sig")
long_df = pd.read_csv(LONG_FILE, encoding="utf-8-sig")

# Chuẩn hoá
with_df["artist_name"] = with_df["artist_name"].astype(str).str.strip()
long_df["artist_name"] = long_df["artist_name"].astype(str).str.strip()
long_df["show"]        = long_df["show"].astype(str).str.strip()

# Danh sách nghệ sĩ cần xét
artists = with_df["artist_name"].dropna().unique().tolist()

# Giữ lại trong long_df chỉ các nghệ sĩ nằm trong danh sách này
long_df = long_df[long_df["artist_name"].isin(artists)].drop_duplicates(["show","artist_name"])

# Tạo ma trận xuất hiện (nghệ sĩ x show)
M = pd.crosstab(long_df["artist_name"], long_df["show"]).astype(int)

# Đảm bảo đủ tất cả nghệ sĩ từ with_df (nếu ai chưa xuất hiện show nào thì thêm dòng 0)
M = M.reindex(artists, fill_value=0)

# Tính ma trận đồng xuất hiện: C = M · Mᵀ
C = M.dot(M.T)

# Bỏ giá trị chéo (tự ghép)
for i in range(len(C)):
    C.iat[i, i] = 0

# Xuất CSV
C.to_csv(OUT_MATRIX, encoding="utf-8-sig")

print(f"Đã tạo ma trận đồng xuất hiện {C.shape[0]} x {C.shape[1]} tại: {OUT_MATRIX}")
# Out:
# Đã tạo ma trận đồng xuất hiện 675 x 675 tại: D:/MangXaHoi/gameshow_vietnam/artist_coappearance_matrix1.csv
